# %%
# Import dependencies
import json
from sqlalchemy import create_engine
import pandas as pd
import pymysql
pymysql.install_as_MySQLdb()
from datetime import datetime, date

# %%
# Import configuration variables
from config import sf_username, sf_password, sf_security_token
from config import remote_db_endpoint, remote_db_port
from config import remote_db_name, remote_db_user, remote_db_pwd

# %%
# Set up simple_salesforce
from simple_salesforce import Salesforce
sf = Salesforce(username=sf_username, password=sf_password, security_token=sf_security_token)

# %%
# Connect to your MySQL database
engine = create_engine(f"mysql://{remote_db_user}:{remote_db_pwd}@{remote_db_endpoint}:{remote_db_port}/{remote_db_name}")
conn = engine.connect()

# %% [markdown]
# ## Query 'staffassignment' table from MySql

# %%
# Query Data
staff_sa = pd.read_sql("SELECT * FROM staffassignment", conn)
staff_sa.head()
# Out:
#    ID_StaffAssignment  ID_Staff  ID_Class               Role   StartDate  \
# 0                   1         1         1  Teacher Assistant  2020-03-16
# 1                   2         4         1  Teacher Assistant  2020-03-16
# 2                   3         3         1         Instructor  2020-03-16
#
#   EndDate
# 0    None
# 1    None
# 2    None

# %% [markdown]
# ## Query Class data from Salesforce in order to Get its 'Record Id'

# %%
sf_class_data = sf.query_all_iter("SELECT Id, Name, ID_Class__c FROM class__c")

# %%
class_sf = []

for data in sf_class_data:
    records = {
        'Class_Id_record': data['Id'],
        'Class Name' : data['Name'],
        'ID_Class__c': data['ID_Class__c']
    }
    
    class_sf.append(records)

# %%
class_sf
# Out:
# [{'Class_Id_record': 'a043h00000Lm9mxAAB',
#   'Class Name': 'a043h00000Lm9mx',
#   'ID_Class__c': 1.0},
#  {'Class_Id_record': 'a043h00000Lm9n7AAB',
#   'Class Name': 'a043h00000Lm9n7',
#   'ID_Class__c': 1.0},
#  {'Class_Id_record': 'a043h00000Lm9nCAAR',
#   'Class Name': 'a043h00000Lm9nC',
#   'ID_Class__c': 2.0},
#  {'Class_Id_record': 'a043h00000Lm9nRAAR',
#   'Class Name': 'a043h00000Lm9nR',
#   'ID_Class__c': 3.0},
#  {'Class_Id_record': 'a043h00000Lm9nbAAB',
#   'Class Name': 'a043h00000Lm9nb',
#   'ID_Class__c': 3.0},
#  {'Class_Id_record': 'a043h00000Lm9ngAAB',
#   'Class Name': 'a043h00000Lm9ng',
#   'ID_Class__c': 4.0},
#  {'Class_Id_record': 'a043h00000Lm9nWAAR',
#   'Class Name': 'a043h00000Lm9nW',
#   'ID_Class__c': 3.0},
#  {'Class_Id_record': 'a043h00000Lm9nqAAB',
#   'Class Name': 'a043h00000Lm9nq',
#   'ID_Class__c': 4.0},
#  {'Class_Id_record': 'a043h00000Lm9nMAAR',
#   'Class Name': 'a043h00000Lm9nM',
#   'ID_Class__c': 2.0},
#  {'Class_Id_record': 'a043h00000Lm9n2AAB',
#   'Class Name': 'a043h00000Lm9n2',
#   'ID_Class__c': 1.0},
#  {'Class_Id_record': 'a043h00000Lm9nHAAR',
#   'Class Name': 'a043h00000Lm9nH',
#   'ID_Class__c': 2.0},
#  {'Class_Id_record': 'a043h00000Lm9nlAAB',
#   'Class Name': 'a043h00000Lm9nl',
#   'ID_Class__c': 4.0},
#  {'Class_Id_record': 'a043h00000Lm9tLAAR',
#   'Class Name': 'a043h00000Lm9tL',
#   'ID_Class__c': 4.0},
#  {'Class_Id_record': 'a043h00000Lm9tQAAR',
#   'Class Name': 'a043h00000Lm9tQ',
#   'ID_Class__c': 4.0},
#  {'Class_Id_record': 'a043h00000Lm9shAAB',
#   'Class Name': 'a043h00000Lm9sh',
#   'ID_Class__c': 1.0},
#  {'Class_Id_record': 'a043h00000Lm9tBAAR',
#   'Class Name': 'a043h00000Lm9tB',
#   'ID_Class__c': 3.0},
#  {'Class_Id_record': 'a043h00000Lm9sXAAR',
#   'Class Name': 'a043h00000Lm9sX',
#   'ID_Class__c': 1.0},
#  {'Class_Id_record': 'a043h00000Lm9tGAAR',
#   'Class Name': 'a043h00000Lm9tG',
#   'ID_Class__c': 4.0},
#  {'Class_Id_record': 'a043h00000Lm9t6AAB',
#   'Class Name': 'a043h00000Lm9t6',
#   'ID_Class__c': 3.0},
#  {'Class_Id_record': 'a043h00000Lm9smAAB',
#   'Class Name': 'a043h00000Lm9sm',
#   'ID_Class__c': 2.0},
#  {'Class_Id_record': 'a043h00000Lm9srAAB',
#   'Class Name': 'a043h00000Lm9sr',
#   'ID_Class__c': 2.0},
#  {'Class_Id_record': 'a043h00000Lm9swAAB',
#   'Class Name': 'a043h00000Lm9sw',
#   'ID_Class__c': 2.0},
#  {'Class_Id_record': 'a043h00000Lm9t1AAB',
#   'Class Name': 'a043h00000Lm9t1',
#   'ID_Class__c': 3.0},
#  {'Class_Id_record': 'a043h00000Lm9scAAB',
#   'Class Name': 'a043h00000Lm9sc',
#   'ID_Class__c': 1.0}]

# %%
class_sf = pd.DataFrame(class_sf)
class_sf.head()
# Out:
#       Class_Id_record       Class Name  ID_Class__c
# 0  a043h00000Lm9mxAAB  a043h00000Lm9mx          1.0
# 1  a043h00000Lm9n7AAB  a043h00000Lm9n7          1.0
# 2  a043h00000Lm9nCAAR  a043h00000Lm9nC          2.0
# 3  a043h00000Lm9nRAAR  a043h00000Lm9nR          3.0
# 4  a043h00000Lm9nbAAB  a043h00000Lm9nb          3.0

# %%
class_sf['ID_Class__c'] = class_sf['ID_Class__c'].astype(int)

# %% [markdown]
# ## Prep. Staffassignment table to be prompt to join with Class table

# %%
# Transform Data to perfectly match between dataframe headers and field names in Salesforce
staff_sa = staff_sa.rename(columns={
                                        'ID_StaffAssignment':'ID_StaffAssignment__c',
                                        'ID_Staff':'ID_Staff__c',
                                        'ID_Class':'ID_Class__c',
                                        'Role':'Name',
                                        'StartDate':'StartDate__c',
                                        'EndDate':'EndDate__c'
                                })
staff_sa.head()
# Out:
#    ID_StaffAssignment__c  ID_Staff__c  ID_Class__c               Name  \
# 0                      1            1            1  Teacher Assistant
# 1                      2            4            1  Teacher Assistant
# 2                      3            3            1         Instructor
#
#   StartDate__c EndDate__c
# 0   2020-03-16       None
# 1   2020-03-16       None
# 2   2020-03-16       None

# %%
'''
### doing this is still making an error of 'Object of type date is not JSON serializable' ###
staff_sa['StartDate__c'] = pd.to_datetime(staff_sa['StartDate__c']).dt.date
staff_sa['EndDate__c'] = pd.to_datetime(staff_sa['EndDate__c']).dt.date
'''
# Out:
# "\n### doing this is still making an error of 'Object of type date is not JSON serializable' ###\nstaff_sa['StartDate__c'] = pd.to_datetime(staff_sa['StartDate__c']).dt.date\nstaff_sa['EndDate__c'] = pd.to_datetime(staff_sa['EndDate__c']).dt.date\n"

# %%
from datetime import datetime, date
staff_sa['StartDate__c'] = staff_sa['StartDate__c'].apply(lambda x: x.strftime('%Y-%m-%d'))
staff_sa['EndDate__c'] = staff_sa['EndDate__c'].apply(lambda x: x.strftime('%Y-%m-%d'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-f08be57c1f5f> in <module>
#       1 from datetime import datetime, date
#       2 staff_sa['StartDate__c'] = staff_sa['StartDate__c'].apply(lambda x: x.strftime('%Y-%m-%d'))
# ----> 3 staff_sa['EndDate__c'] = staff_sa['EndDate__c'].apply(lambda x: x.strftime('%Y-%m-%d'))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-29-f08be57c1f5f> in <lambda>(x)
#       1 from datetime import datetime, date
#       2 staff_sa['StartDate__c'] = staff_sa['StartDate__c'].apply(lambda x: x.strftime('%Y-%m-%d'))
# ----> 3 staff_sa['EndDate__c'] = staff_sa['EndDate__c'].apply(lambda x: x.strftime('%Y-%m-%d'))
#
# AttributeError: 'NoneType' object has no attribute 'strftime'

# %% [markdown]
# ## Join tables

# %%
staff_x_class = staff_sa.merge(class_sf)
staff_x_class.head()
# Out:
#    ID_StaffAssignment__c  ID_Staff__c  ID_Class__c               Name  \
# 0                      1            1            1  Teacher Assistant
# 1                      1            1            1  Teacher Assistant
# 2                      1            1            1  Teacher Assistant
# 3                      1            1            1  Teacher Assistant
# 4                      1            1            1  Teacher Assistant
#
#   StartDate__c EndDate__c     Class_Id_record       Class Name
# 0   2020-03-16       None  a043h00000Lm9mxAAB  a043h00000Lm9mx
# 1   2020-03-16       None  a043h00000Lm9n7AAB  a043h00000Lm9n7
# 2   2020-03-16       None  a043h00000Lm9n2AAB  a043h00000Lm9n2
# 3   2020-03-16       None  a043h00000Lm9shAAB  a043h00000Lm9sh
# 4   2020-03-16       None  a043h00000Lm9sXAAR  a043h00000Lm9sX

# %%
# Convert DataFrame to a list of dictionaries --> This can help facilitate a bulk insert
staff_load = staff_x_class.to_dict(orient='record')
staff_load
# Out:
# [{'ID_StaffAssignment__c': 1,
#   'ID_Staff__c': 1,
#   'ID_Class__c': 1,
#   'Name': 'Teacher Assistant',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9mxAAB',
#   'Class Name': 'a043h00000Lm9mx'},
#  {'ID_StaffAssignment__c': 1,
#   'ID_Staff__c': 1,
#   'ID_Class__c': 1,
#   'Name': 'Teacher Assistant',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9n7AAB',
#   'Class Name': 'a043h00000Lm9n7'},
#  {'ID_StaffAssignment__c': 1,
#   'ID_Staff__c': 1,
#   'ID_Class__c': 1,
#   'Name': 'Teacher Assistant',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9n2AAB',
#   'Class Name': 'a043h00000Lm9n2'},
#  {'ID_StaffAssignment__c': 1,
#   'ID_Staff__c': 1,
#   'ID_Class__c': 1,
#   'Name': 'Teacher Assistant',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9shAAB',
#   'Class Name': 'a043h00000Lm9sh'},
#  {'ID_StaffAssignment__c': 1,
#   'ID_Staff__c': 1,
#   'ID_Class__c': 1,
#   'Name': 'Teacher Assistant',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9sXAAR',
#   'Class Name': 'a043h00000Lm9sX'},
#  {'ID_StaffAssignment__c': 1,
#   'ID_Staff__c': 1,
#   'ID_Class__c': 1,
#   'Name': 'Teacher Assistant',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9scAAB',
#   'Class Name': 'a043h00000Lm9sc'},
#  {'ID_StaffAssignment__c': 2,
#   'ID_Staff__c': 4,
#   'ID_Class__c': 1,
#   'Name': 'Teacher Assistant',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9mxAAB',
#   'Class Name': 'a043h00000Lm9mx'},
#  {'ID_StaffAssignment__c': 2,
#   'ID_Staff__c': 4,
#   'ID_Class__c': 1,
#   'Name': 'Teacher Assistant',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9n7AAB',
#   'Class Name': 'a043h00000Lm9n7'},
#  {'ID_StaffAssignment__c': 2,
#   'ID_Staff__c': 4,
#   'ID_Class__c': 1,
#   'Name': 'Teacher Assistant',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9n2AAB',
#   'Class Name': 'a043h00000Lm9n2'},
#  {'ID_StaffAssignment__c': 2,
#   'ID_Staff__c': 4,
#   'ID_Class__c': 1,
#   'Name': 'Teacher Assistant',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9shAAB',
#   'Class Name': 'a043h00000Lm9sh'},
#  {'ID_StaffAssignment__c': 2,
#   'ID_Staff__c': 4,
#   'ID_Class__c': 1,
#   'Name': 'Teacher Assistant',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9sXAAR',
#   'Class Name': 'a043h00000Lm9sX'},
#  {'ID_StaffAssignment__c': 2,
#   'ID_Staff__c': 4,
#   'ID_Class__c': 1,
#   'Name': 'Teacher Assistant',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9scAAB',
#   'Class Name': 'a043h00000Lm9sc'},
#  {'ID_StaffAssignment__c': 3,
#   'ID_Staff__c': 3,
#   'ID_Class__c': 1,
#   'Name': 'Instructor',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9mxAAB',
#   'Class Name': 'a043h00000Lm9mx'},
#  {'ID_StaffAssignment__c': 3,
#   'ID_Staff__c': 3,
#   'ID_Class__c': 1,
#   'Name': 'Instructor',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9n7AAB',
#   'Class Name': 'a043h00000Lm9n7'},
#  {'ID_StaffAssignment__c': 3,
#   'ID_Staff__c': 3,
#   'ID_Class__c': 1,
#   'Name': 'Instructor',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9n2AAB',
#   'Class Name': 'a043h00000Lm9n2'},
#  {'ID_StaffAssignment__c': 3,
#   'ID_Staff__c': 3,
#   'ID_Class__c': 1,
#   'Name': 'Instructor',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9shAAB',
#   'Class Name': 'a043h00000Lm9sh'},
#  {'ID_StaffAssignment__c': 3,
#   'ID_Staff__c': 3,
#   'ID_Class__c': 1,
#   'Name': 'Instructor',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9sXAAR',
#   'Class Name': 'a043h00000Lm9sX'},
#  {'ID_StaffAssignment__c': 3,
#   'ID_Staff__c': 3,
#   'ID_Class__c': 1,
#   'Name': 'Instructor',
#   'StartDate__c': '2020-03-16',
#   'EndDate__c': None,
#   'Class_Id_record': 'a043h00000Lm9scAAB',
#   'Class Name': 'a043h00000Lm9sc'}]

# %% [markdown]
# ## Insert 'Staffassignment' records

# %%
for row in staff_load:
    
    record = {
        'ID_StaffAssignment__c': row['ID_StaffAssignment__c'],
        'ID_Staff__c': row['ID_Staff__c'],
        'ID_Class__c':row['ID_Class__c'],
        'Name' : row['Name'],
        'StartDate__c':row['StartDate__c'],
        'EndDate__c':row['EndDate__c']
    }
    try:
        sf.Staff_Assignment__c.create(record)
    except Exception as e:
        print(e)

# %%
'''
# Inserting rows in bulk for Staff Assignment table on Salesforce
try:
    sf.bulk.Staff_Assignment__c.insert(staff_load)
except Exception as e:
    print(e)
'''
